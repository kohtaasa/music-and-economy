# %%
import pandas as pd

# %%
bil = pd.read_pickle('/Users/kohtaasakura/PyDev/grad_thesis/billboard/billboard_weekly.pkl')
bil
# Out:
#               date                     song                         artist  \
# 0       2021-11-06               Easy On Me                          Adele
# 1       2021-11-06                     Stay  The Kid LAROI & Justin Bieber
# 2       2021-11-06            Industry Baby        Lil Nas X & Jack Harlow
# 3       2021-11-06               Fancy Like                   Walker Hayes
# 4       2021-11-06               Bad Habits                     Ed Sheeran
# ...            ...                      ...                            ...
# 254882  1973-01-06      The Red Back Spider            Brownsville Station
# 254883  1973-01-06  She's Got To Be A Saint                      Ray Price
# 254884  1973-01-06                Soul Song                   Joe Stampley
# 254885  1973-01-06      On And Off (Part 1)                      Anacostia
# 254886  1973-01-06     Slow Motion (Part 1)                Johnny Williams
#
#                        song_id
# 0       0gplL1WMoJ6iYaPgMCL0gX
# ...

# %%
audio = pd.read_pickle('/Users/kohtaasakura/PyDev/grad_thesis/spotify_data/billboard_audio_features.pkl')
audio = audio.drop_duplicates()
audio
# Out:
#          acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0              0.5780         0.604       224695   0.366          0.000000
# 2              0.0383         0.591       141806   0.764          0.000000
# 5              0.0203         0.736       212000   0.704          0.000000
# 9              0.1110         0.647       161853   0.765          0.000000
# 14             0.0451         0.807       230747   0.893          0.000028
# ...               ...           ...          ...     ...               ...
# 1003120        0.2630         0.598       194240   0.560          0.000095
# 1003202        0.2150         0.512       153173   0.977          0.000000
# 1003285        0.1630         0.535       183360   0.366          0.000000
# 1003369        0.1400         0.693       317213   0.370          0.000199
# 1003454        0.0174         0.528       370427   0.921          0.000186
#
# ...

# %%
bil['uri'] = 'spotify:track:' + bil['song_id']
df = pd.merge(bil, audio, how='left', on='uri')
df
# Out:
#               date                     song                         artist  \
# 0       2021-11-06               Easy On Me                          Adele
# 1       2021-11-06                     Stay  The Kid LAROI & Justin Bieber
# 2       2021-11-06            Industry Baby        Lil Nas X & Jack Harlow
# 3       2021-11-06               Fancy Like                   Walker Hayes
# 4       2021-11-06               Bad Habits                     Ed Sheeran
# ...            ...                      ...                            ...
# 254882  1973-01-06      The Red Back Spider            Brownsville Station
# 254883  1973-01-06  She's Got To Be A Saint                      Ray Price
# 254884  1973-01-06                Soul Song                   Joe Stampley
# 254885  1973-01-06      On And Off (Part 1)                      Anacostia
# 254886  1973-01-06     Slow Motion (Part 1)                Johnny Williams
#
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
# df = df[df['date'] >= '1975-01-01']
df = df[df['date'] >= '2017-01-01']
df['year'] = df['date'].dt.strftime('%Y')
df = df.drop('date', axis=1).drop_duplicates()
df
# Out:
# /var/folders/bk/syp6nsbn40j6khhtbc03r73c0000gn/T/ipykernel_31565/3343542505.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['date'].dt.strftime('%Y')
#                           song                               artist  \
# 0                   Easy On Me                                Adele
# 1                         Stay        The Kid LAROI & Justin Bieber
# 2                Industry Baby              Lil Nas X & Jack Harlow
# 3                   Fancy Like                         Walker Hayes
# 4                   Bad Habits                           Ed Sheeran
# ...                        ...                                  ...
# 25289          Ville Mentality                              J. Cole
# ...

# %%
df.sort_values(by='acousticness', ascending=False)
# Out:
#                         song                           artist  \
# 4956                    Iris                  Phoebe & Maggie
# 24543      Don't Let Me Down  The Chainsmokers Featuring Daya
# 45494        Nothing Like Us                    Justin Bieber
# 41983  Make You Feel My Love                        Glee Cast
# 12344  When The Party's Over                    Billie Eilish
# ...                      ...                              ...
# 11493                    Uno                          Ambjaay
# 28146                 My Boo                  Ghost Town DJ's
# 30995          Temporary Fix                    One Direction
# 7583            Harlem Shake      Future Featuring Young Thug
# 34379                Failure                Breaking Benjamin
#
#                       song_id                                   uri  \
# 4956   4Z1xN1J50aIn1kqDmy0RNG  spotify:track:4Z1xN1J50aIn1kqDmy0RNG
# 24543  0OZjP4XoAOdXPhgSIypwqu  spotify:track:0OZjP4XoAOdXPhgSIypwqu
# ...

# %%
df.sort_values(by='acousticness').head(20)
# Out:
#                            song  \
# 34379                   Failure
# 7583               Harlem Shake
# 30995             Temporary Fix
# 28146                    My Boo
# 11493                       Uno
# 45946   Blow Me (One Last Kiss)
# 42891           What About Love
# 27887  Ain't No Stopping Us Now
# 32094           Jet Black Heart
# 44297        Memories Back Then
# 14482                       F&N
# 40043            Safe And Sound
# 34246                   Animals
# 5391           Bloody Valentine
# 30336              Hit The Quan
# 19694         The Greatest Show
# 14885                       1.5
# 11972                      BLOW
# 9990                 Follow God
# 10435                    God Is
#
#                                                   artist  \
# 34379                                  Breaking Benjamin
# 7583                         Future Featuring Young Thug
# 30995                                      One Direction
# ...

# %%
df.sort_values(by='danceability', ascending=False).head(30)
# Out:
#                                    song  \
# 24271  Cash Me Outside (#CashMeOutside)
# 11493                               Uno
# 10698                       Bad Bad Bad
# 11483                          Lil Baby
# 24277                         Make Love
# 17695                              Drip
# 21882                          Bad Liar
# 13191                      Pure Cocaine
# 35547                          Anaconda
# 15243                        Yes Indeed
# 7780                           Low Down
# 15899                           Lose It
# 11454                   What's The Move
# 33997                           Trouble
# 25049                    Too Much Sauce
# 28975                       Best Friend
# 13985                              Lick
# 6384                         Don't Rush
# 13084                          CHopstix
# 2754                           Cry Baby
# 22888                        Peek A Boo
# 2998                            Buss It
# ...

# %%
df.sort_values(by='danceability').head(30)
# Out:
#                                            song  \
# 38773                Can't Help Falling In Love
# 38569                             Ultraviolence
# 30480                                Hallelujah
# 852                        No Child Left Behind
# 9668                   Happy Xmas (War Is Over)
# 26296                           Forever Country
# 30571                      Climb Every Mountain
# 34499                          The Hanging Tree
# 8320                                Alone Again
# 43689                             Turn The Page
# 42858                         Hopeless Wanderer
# 28293                     Every Breath You Take
# 4449                 I'll Be Home For Christmas
# 4327   It's The Most Wonderful Time Of The Year
# 4493                               Silent Night
# 10462                             Jesus Is Lord
# 8379                          Until I Bleed Out
# 28569                         Pray You Catch Me
# ...

# %%
df.sort_values(by='energy', ascending=False).head(30)
# Out:
#                            song  \
# 44297        Memories Back Then
# 41196              Days Of Gold
# 28607            When Doves Cry
# 14482                       F&N
# 44659                  Pom Poms
# 31078             Anything Goes
# 26190                   Rock On
# 36996                  Bend Ova
# 27591            Bored To Death
# 29089        Home Alone Tonight
# 44779               The Phoenix
# 38148                    Timber
# 31542               Uma Thurman
# 38744       Slave To The Rhythm
# 39980  Everything Is AWESOME!!!
# 35981              Day Drinking
# 42590               Rock N Roll
# 12676                    Higher
# 40595                How I Feel
# 8099                 Boss Bitch
# 41778                Round Here
# 14227                     Alone
# 34680                  Sun Daze
# 36247        Leave The Night On
# 37573      She Looks So Perfect
# 36074                     Booty
# 5050              Lovin' On You
# 41949                    Cruise
# ...

# %%
df.sort_values(by='energy').head(20)
# Out:
#                                   song  \
# 9247                           Circles
# 24543                Don't Let Me Down
# 13462               Listen Before I Go
# 27442                         Lost Boy
# 4956                              Iris
# 23096                       Either Way
# 15083           Difference (Interlude)
# 45892                I Dreamed A Dream
# 34499                 The Hanging Tree
# 4449        I'll Be Home For Christmas
# 40388    A Man Who Was Gonna Die Young
# 12344            When The Party's Over
# 45996                        On My Own
# 41983            Make You Feel My Love
# 39183  Do You Want To Build A Snowman?
# 13197                            Xanny
# 1268                     Getting Older
# 13452                       I Love You
# 28662                          Forward
# 39040                    Say Something
#
#                                                 artist  \
# 9247                                        Mac Miller
# ...

# %%
df.sort_values(by='liveness', ascending=False)
# Out:
#                            song                                    artist  \
# 41          Leave The Door Open  Silk Sonic (Bruno Mars & Anderson .Paak)
# 9668   Happy Xmas (War Is Over)                               John Legend
# 5147                   Thriller                           Michael Jackson
# 10443                  Thriller                           Michael Jackson
# 15630                  Thriller                           Michael Jackson
# ...                         ...                                       ...
# 17880        For The First Time                             Darius Rucker
# 9898                Cuban Links                    Rod Wave & Kevin Gates
# 16688       The Light Is Coming       Ariana Grande Featuring Nicki Minaj
# 23489                Hard Times                                  Paramore
# 17749                   Finesse                      Bruno Mars & Cardi B
#
#                       song_id                                   uri  \
# ...

# %%
df.sort_values(by='liveness').head(30)
# Out:
#                                        song  \
# 27485                            M.I.L.F. $
# 37648                          Ain't It Fun
# 17749                               Finesse
# 27567                               T-Shirt
# 23489                            Hard Times
# 31467                           House Party
# 16688                   The Light Is Coming
# 9898                            Cuban Links
# 17880                    For The First Time
# 42091              Little Bit Of Everything
# 43548              I Knew You Were Trouble.
# 27687                        Messin' Around
# 29621                          Uptown Funk!
# 36470                  I Won't Let You Down
# 41744  Cups (Pitch Perfect's When I'm Gone)
# 10172                    Every Little Thing
# 38713                           Billie Jean
# 36484                         American Kids
# 40048                    Whatever She's Got
# 42891                       What About Love
# ...

# %%
df.sort_values(by='loudness', ascending=False).head(30)
# Out:
#                              song  \
# 44297          Memories Back Then
# 17586        Welcome To The Party
# 25677                        Move
# 22596                  Good Drank
# 29089          Home Alone Tonight
# 32785             Little Toy Guns
# 40595                  How I Feel
# 43093                   Play Hard
# 13789      What Makes You Country
# 12856                  Baby Shark
# 26898                Church Bells
# 30999                Never Enough
# 18284            Ye vs The People
# 5287          Whole Lotta Choppas
# 12676                      Higher
# 40291           Midnight Memories
# 23669              Play That Song
# 45793      Live While We're Young
# 12391                   Rescue Me
# 3287                   Daywalker!
# 382                     The Feels
# 39398                Take Me Home
# 14172                      Uproar
# 44659                    Pom Poms
# 13399                 Victory Lap
# 43399          Live For The Night
# ...

# %%
df.sort_values(by='loudness').head(30)
# Out:
#                                   song  \
# 24543                Don't Let Me Down
# 13462               Listen Before I Go
# 4956                              Iris
# 8194                         Thug Life
# 30074                    I'll Show You
# 13452                       I Love You
# 34499                 The Hanging Tree
# 13197                            Xanny
# 16975                            Ocean
# 34937                            Don't
# 77                                 WFM
# 23338          Can't Stop The Feeling!
# 1268                     Getting Older
# 45892                I Dreamed A Dream
# 23553                           Blood.
# 1289                    Halley's Comet
# 4432                    Blue Christmas
# 40388    A Man Who Was Gonna Die Young
# 39708     We Might Be Dead By Tomorrow
# 4419                   White Christmas
# 38692                       Don't Stop
# 21595                          Revenge
# 9644            Baby It's Cold Outside
# ...

# %%
df.sort_values(by='speechiness', ascending=False).head(30)
# Out:
#                                     song  \
# 27786                       Think Of You
# 17197                        8 Out Of 10
# 16691                      Growing Pains
# 15063                         Train Food
# 17595                   Cop Shot The Kid
# 17988                                ATM
# 7591      Beautiful Pain (Losin My Mind)
# 4599                      Beautiful Trip
# 33                              Wockesha
# 23562                         Duckworth.
# 34047                               Only
# 32477                         Charged Up
# 15161                               Time
# 1873                     No More Parties
# 8698                       Can't Explain
# 13579                           Splashin
# 1744                          Lumberjack
# 18399                          Best Life
# 26090              Why You Always Hatin?
# 42163                           Too Much
# 6199                                  21
# 5897                         Dirty Stick
# ...

# %%
df.sort_values(by='speechiness').head(30)
# Out:
#                            song                           artist  \
# 16120                   Perfect                       Ed Sheeran
# 2143             Hell Of A View                      Eric Church
# 45995       Did It For The Girl                       Greg Bates
# 4477             The First Noel                    Gabby Barrett
# 66             Whiskey And Rain                      Michael Ray
# 13862                  Burn Out                          Midland
# 42371                      Easy                      Sheryl Crow
# 44878                   Tornado                  Little Big Town
# 3775                        865                    Morgan Wallen
# 42489       When I See This Bar                    Kenny Chesney
# 192                    You Time                  Scotty McCreery
# 34097                   Imagine                Sawyer Fredericks
# 10085          Tip Of My Tongue                    Kenny Chesney
# ...

# %%
df.sort_values(by='tempo', ascending=False).head(30)
# Out:
#                                            song  \
# 11362                    Soon You'll Get Better
# 17595                          Cop Shot The Kid
# 11296                                   Love Me
# 15448                                  Big Bank
# 4668                                  7 Summers
# 3834                                  7 Summers
# 42                           Thinking 'Bout You
# 15678                                Drunk Girl
# 16979                                   One Day
# 4435          Mele Kalikimaka (Merry Christmas)
# 11944                                Pure Water
# 4327   It's The Most Wonderful Time Of The Year
# 14909  It's The Most Wonderful Time Of The Year
# 4506   It's The Most Wonderful Time Of The Year
# 9714   It's The Most Wonderful Time Of The Year
# 20134  It's The Most Wonderful Time Of The Year
# 24689                             Dirty Laundry
# 69                              Jugaste y Sufri
# ...

# %%
df.sort_values(by='tempo').head(30)
# Out:
#                                          song  \
# 28989                       Tennessee Whiskey
# 34499                        The Hanging Tree
# 24396                               No Favors
# 41728                              Hold Tight
# 31087                                    Halo
# 19199                                    Rock
# 13478                                       8
# 13984                                 Imagine
# 16577                                 Changes
# 34881                                  Preach
# 8320                              Alone Again
# 6746                                I Want It
# 10165                                The Take
# 4311        Rockin' Around The Christmas Tree
# 12751                               Celebrate
# 9349                                    Lover
# 23181                                  Prblms
# 4448   Have Yourself A Merry Little Christmas
# 9263                            Hand Me Downs
# ...

# %%
df.sort_values(by='valence', ascending=False)
# Out:
#                                                     song  \
# 4425   Here Comes Santa Claus (Right Down Santa Claus...
# 4568   Here Comes Santa Claus (Right Down Santa Claus...
# 14934  Here Comes Santa Claus (Right Down Santa Claus...
# 9746   Here Comes Santa Claus (Right Down Santa Claus...
# 2164                                               amari
# ...                                                  ...
# 13874                                               Whip
# 17266                                              Jaded
# 6173                                            The Plan
# 11694                                   Days In The East
# 3961                                    Lo Vas A Olvidar
#
#                                 artist                 song_id  \
# 4425                        Gene Autry  25leEEaz1gIpp7o21Fqyjo
# 4568                        Gene Autry  25leEEaz1gIpp7o21Fqyjo
# 14934                       Gene Autry  25leEEaz1gIpp7o21Fqyjo
# ...

# %%
df.sort_values(by='valence')
# Out:
#                                                     song  \
# 3961                                    Lo Vas A Olvidar
# 11694                                   Days In The East
# 6173                                            The Plan
# 17266                                              Jaded
# 13874                                               Whip
# ...                                                  ...
# 2164                                               amari
# 4425   Here Comes Santa Claus (Right Down Santa Claus...
# 14934  Here Comes Santa Claus (Right Down Santa Claus...
# 9746   Here Comes Santa Claus (Right Down Santa Claus...
# 4568   Here Comes Santa Claus (Right Down Santa Claus...
#
#                                 artist                 song_id  \
# 3961           Billie Eilish & ROSALIA  0psS4i5YooJrXfDnGvWRLi
# 11694                            Drake  4czcw3NVLY0of5hTD7OufN
# 6173                      Travis Scott  551xyaSJsg8hILXFq9JdST
# ...
