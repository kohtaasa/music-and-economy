# %% [markdown]
# # Billboard Hot 100 and Unemployment Rate Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import statsmodels.api as sm
import numpy as np
import seaborn as sns
import datetime as dt

# %% [markdown]
# ## 1. Music Data

# %% [markdown]
# ### Load billboard data with spotify track IDs

# %%
bil = pd.read_pickle('/Users/kohtaasakura/PyDev/grad_thesis/billboard/billboard_weekly.pkl')
bil
# Out:
#               date                     song                         artist  \
# 0       2021-11-06               Easy On Me                          Adele
# 1       2021-11-06                     Stay  The Kid LAROI & Justin Bieber
# 2       2021-11-06            Industry Baby        Lil Nas X & Jack Harlow
# 3       2021-11-06               Fancy Like                   Walker Hayes
# 4       2021-11-06               Bad Habits                     Ed Sheeran
# ...            ...                      ...                            ...
# 254882  1973-01-06      The Red Back Spider            Brownsville Station
# 254883  1973-01-06  She's Got To Be A Saint                      Ray Price
# 254884  1973-01-06                Soul Song                   Joe Stampley
# 254885  1973-01-06      On And Off (Part 1)                      Anacostia
# 254886  1973-01-06     Slow Motion (Part 1)                Johnny Williams
#
#                        song_id
# 0       0gplL1WMoJ6iYaPgMCL0gX
# 1       5HCyWlXZPP0y6Gqq8TgA20
# 2       27NovPIUIRrOZoCHxABJwK
# 3       58UKC45GPNTflCN6nwCUeF
# 4       3rmo8F54jFF8OgYsqTxm5d
# ...                        ...
# 254882  6UGHk2cmbDC1oidVjXcCKo
# 254883  0md3dDLRwrsgBQ59CfgmXO
# 254884  5r9h2NUZTuQD3mvZXfMGmU
# 254885  37Edt4Ro7v2STgu75Fj35o
# 254886  6EdVvkxAYAgT3DXW8Op4ZH
#
# [254887 rows x 4 columns]

# %% [markdown]
# ### Load audio features

# %%
audio = pd.read_pickle('/Users/kohtaasakura/PyDev/grad_thesis/spotify_data/billboard_audio_features.pkl')
audio = audio.drop_duplicates()
audio
# Out:
#          acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0              0.5780         0.604       224695   0.366          0.000000
# 2              0.0383         0.591       141806   0.764          0.000000
# 5              0.0203         0.736       212000   0.704          0.000000
# 9              0.1110         0.647       161853   0.765          0.000000
# 14             0.0451         0.807       230747   0.893          0.000028
# ...               ...           ...          ...     ...               ...
# 1003120        0.2630         0.598       194240   0.560          0.000095
# 1003202        0.2150         0.512       153173   0.977          0.000000
# 1003285        0.1630         0.535       183360   0.366          0.000000
# 1003369        0.1400         0.693       317213   0.370          0.000199
# 1003454        0.0174         0.528       370427   0.921          0.000186
#
#          key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0          5    0.1330    -7.519     1       0.0282  141.981               4
# 2          1    0.1030    -5.484     1       0.0483  169.928               4
# 5          3    0.0501    -7.409     0       0.0615  149.995               4
# 9          1    0.3150    -6.459     1       0.0600   79.994               4
# 14        11    0.3660    -3.745     0       0.0347  126.011               4
# ...      ...       ...       ...   ...          ...      ...             ...
# 1003120   10    0.4300   -10.529     1       0.0290  110.402               4
# 1003202    2    0.3430    -4.505     1       0.0671  120.165               4
# 1003285    9    0.0791   -16.004     1       0.0496   88.732               4
# 1003369    7    0.4600   -13.270     1       0.0295  102.827               4
# 1003454    2    0.0472    -7.640     1       0.0524  144.368               4
#
#                                           uri  valence
# 0        spotify:track:0gplL1WMoJ6iYaPgMCL0gX    0.130
# 2        spotify:track:5HCyWlXZPP0y6Gqq8TgA20    0.478
# 5        spotify:track:27NovPIUIRrOZoCHxABJwK    0.894
# 9        spotify:track:58UKC45GPNTflCN6nwCUeF    0.855
# 14       spotify:track:3rmo8F54jFF8OgYsqTxm5d    0.537
# ...                                       ...      ...
# 1003120  spotify:track:6WdhPUH1mvuvtmDjLSSAZn    0.676
# 1003202  spotify:track:6LqbJXriVJyqJCd9jYoPqP    0.731
# 1003285  spotify:track:3BmQL02PItbRsBL6j7VJc3    0.590
# 1003369  spotify:track:0WTCCeS8DRcFGOu43p0A2C    0.312
# 1003454  spotify:track:6UGHk2cmbDC1oidVjXcCKo    0.298
#
# [19884 rows x 14 columns]

# %%
audio.describe()
# Out:
#        acousticness  danceability   duration_ms        energy  \
# count  19884.000000  19884.000000  1.988400e+04  19884.000000
# mean       0.212193      0.629513  2.385928e+05      0.650190
# std        0.239991      0.149403  6.248940e+04      0.190454
# min        0.000002      0.058600  2.968800e+04      0.000530
# 25%        0.027900      0.534000  2.016930e+05      0.521000
# 50%        0.114000      0.638000  2.308805e+05      0.670000
# 75%        0.321250      0.736000  2.656670e+05      0.801000
# max        0.996000      0.988000  1.561133e+06      0.998000
#
#        instrumentalness           key      liveness      loudness  \
# count      19884.000000  19884.000000  19884.000000  19884.000000
# mean           0.035178      5.262321      0.183996     -8.075150
# std            0.145348      3.594478      0.153683      3.668177
# min            0.000000      0.000000      0.014600    -42.391000
# 25%            0.000000      2.000000      0.088800    -10.191250
# 50%            0.000004      5.000000      0.125000     -7.338000
# 75%            0.000500      8.000000      0.234000     -5.399750
# max            0.986000     11.000000      0.997000      2.291000
#
#                mode   speechiness         tempo  time_signature       valence
# count  19884.000000  19884.000000  19884.000000     19884.00000  19884.000000
# mean       0.677731      0.086314    120.841825         3.96203      0.571619
# std        0.467357      0.094940     27.838293         0.27249      0.240669
# min        0.000000      0.022000     36.998000         1.00000      0.000010
# 25%        0.000000      0.033300     99.826000         4.00000      0.377000
# 50%        1.000000      0.045400    119.922000         4.00000      0.585000
# 75%        1.000000      0.087000    137.451250         4.00000      0.771000
# max        1.000000      0.951000    218.363000         5.00000      0.991000

# %% [markdown]
# ### Histogram

# %%
plt.rcParams['font.size'] = 10
fig, ax = plt.subplots(figsize=(20,20))

audio.hist(ax=ax, bins=35)
# Out:
# /var/folders/bk/syp6nsbn40j6khhtbc03r73c0000gn/T/ipykernel_7383/1716794225.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   audio.hist(ax=ax, bins=35)
# array([[<AxesSubplot:title={'center':'acousticness'}>,
#         <AxesSubplot:title={'center':'danceability'}>,
#         <AxesSubplot:title={'center':'duration_ms'}>,
#         <AxesSubplot:title={'center':'energy'}>],
#        [<AxesSubplot:title={'center':'instrumentalness'}>,
#         <AxesSubplot:title={'center':'key'}>,
#         <AxesSubplot:title={'center':'liveness'}>,
#         <AxesSubplot:title={'center':'loudness'}>],
#        [<AxesSubplot:title={'center':'mode'}>,
#         <AxesSubplot:title={'center':'speechiness'}>,
#         <AxesSubplot:title={'center':'tempo'}>,
#         <AxesSubplot:title={'center':'time_signature'}>],
#        [<AxesSubplot:title={'center':'valence'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
bil['uri'] = 'spotify:track:' + bil['song_id']
bil
# Out:
#               date                     song                         artist  \
# 0       2021-11-06               Easy On Me                          Adele
# 1       2021-11-06                     Stay  The Kid LAROI & Justin Bieber
# 2       2021-11-06            Industry Baby        Lil Nas X & Jack Harlow
# 3       2021-11-06               Fancy Like                   Walker Hayes
# 4       2021-11-06               Bad Habits                     Ed Sheeran
# ...            ...                      ...                            ...
# 254882  1973-01-06      The Red Back Spider            Brownsville Station
# 254883  1973-01-06  She's Got To Be A Saint                      Ray Price
# 254884  1973-01-06                Soul Song                   Joe Stampley
# 254885  1973-01-06      On And Off (Part 1)                      Anacostia
# 254886  1973-01-06     Slow Motion (Part 1)                Johnny Williams
#
#                        song_id                                   uri
# 0       0gplL1WMoJ6iYaPgMCL0gX  spotify:track:0gplL1WMoJ6iYaPgMCL0gX
# 1       5HCyWlXZPP0y6Gqq8TgA20  spotify:track:5HCyWlXZPP0y6Gqq8TgA20
# 2       27NovPIUIRrOZoCHxABJwK  spotify:track:27NovPIUIRrOZoCHxABJwK
# 3       58UKC45GPNTflCN6nwCUeF  spotify:track:58UKC45GPNTflCN6nwCUeF
# 4       3rmo8F54jFF8OgYsqTxm5d  spotify:track:3rmo8F54jFF8OgYsqTxm5d
# ...                        ...                                   ...
# 254882  6UGHk2cmbDC1oidVjXcCKo  spotify:track:6UGHk2cmbDC1oidVjXcCKo
# 254883  0md3dDLRwrsgBQ59CfgmXO  spotify:track:0md3dDLRwrsgBQ59CfgmXO
# 254884  5r9h2NUZTuQD3mvZXfMGmU  spotify:track:5r9h2NUZTuQD3mvZXfMGmU
# 254885  37Edt4Ro7v2STgu75Fj35o  spotify:track:37Edt4Ro7v2STgu75Fj35o
# 254886  6EdVvkxAYAgT3DXW8Op4ZH  spotify:track:6EdVvkxAYAgT3DXW8Op4ZH
#
# [254887 rows x 5 columns]

# %% [markdown]
# ### Merge billboard data and audio features

# %%
merged = pd.merge(bil, audio, how='left', on='uri')
merged
# Out:
#               date                     song                         artist  \
# 0       2021-11-06               Easy On Me                          Adele
# 1       2021-11-06                     Stay  The Kid LAROI & Justin Bieber
# 2       2021-11-06            Industry Baby        Lil Nas X & Jack Harlow
# 3       2021-11-06               Fancy Like                   Walker Hayes
# 4       2021-11-06               Bad Habits                     Ed Sheeran
# ...            ...                      ...                            ...
# 254882  1973-01-06      The Red Back Spider            Brownsville Station
# 254883  1973-01-06  She's Got To Be A Saint                      Ray Price
# 254884  1973-01-06                Soul Song                   Joe Stampley
# 254885  1973-01-06      On And Off (Part 1)                      Anacostia
# 254886  1973-01-06     Slow Motion (Part 1)                Johnny Williams
#
#                        song_id                                   uri  \
# 0       0gplL1WMoJ6iYaPgMCL0gX  spotify:track:0gplL1WMoJ6iYaPgMCL0gX
# 1       5HCyWlXZPP0y6Gqq8TgA20  spotify:track:5HCyWlXZPP0y6Gqq8TgA20
# 2       27NovPIUIRrOZoCHxABJwK  spotify:track:27NovPIUIRrOZoCHxABJwK
# 3       58UKC45GPNTflCN6nwCUeF  spotify:track:58UKC45GPNTflCN6nwCUeF
# 4       3rmo8F54jFF8OgYsqTxm5d  spotify:track:3rmo8F54jFF8OgYsqTxm5d
# ...                        ...                                   ...
# 254882  6UGHk2cmbDC1oidVjXcCKo  spotify:track:6UGHk2cmbDC1oidVjXcCKo
# 254883  0md3dDLRwrsgBQ59CfgmXO  spotify:track:0md3dDLRwrsgBQ59CfgmXO
# 254884  5r9h2NUZTuQD3mvZXfMGmU  spotify:track:5r9h2NUZTuQD3mvZXfMGmU
# 254885  37Edt4Ro7v2STgu75Fj35o  spotify:track:37Edt4Ro7v2STgu75Fj35o
# 254886  6EdVvkxAYAgT3DXW8Op4ZH  spotify:track:6EdVvkxAYAgT3DXW8Op4ZH
#
#         acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0             0.5780         0.604     224695.0   0.366          0.000000
# 1             0.0383         0.591     141806.0   0.764          0.000000
# 2             0.0203         0.736     212000.0   0.704          0.000000
# 3             0.1110         0.647     161853.0   0.765          0.000000
# 4             0.0451         0.807     230747.0   0.893          0.000028
# ...              ...           ...          ...     ...               ...
# 254882        0.0174         0.528     370427.0   0.921          0.000186
# 254883        0.8580         0.414     228267.0   0.299          0.212000
# 254884        0.7010         0.673     167483.0   0.595          0.000000
# 254885        0.0621         0.696     136276.0   0.602          0.000000
# 254886        0.0874         0.597     177827.0   0.744          0.000004
#
#          key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 0        5.0    0.1330    -7.519   1.0       0.0282  141.981             4.0
# 1        1.0    0.1030    -5.484   1.0       0.0483  169.928             4.0
# 2        3.0    0.0501    -7.409   0.0       0.0615  149.995             4.0
# 3        1.0    0.3150    -6.459   1.0       0.0600   79.994             4.0
# 4       11.0    0.3660    -3.745   0.0       0.0347  126.011             4.0
# ...      ...       ...       ...   ...          ...      ...             ...
# 254882   2.0    0.0472    -7.640   1.0       0.0524  144.368             4.0
# 254883  10.0    0.1280   -12.293   1.0       0.0303   88.516             3.0
# 254884   1.0    0.1290    -7.766   1.0       0.0418  132.019             4.0
# 254885   1.0    0.1370    -3.123   1.0       0.3480  175.147             4.0
# 254886   2.0    0.1130    -9.751   1.0       0.0506  107.531             4.0
#
#         valence
# 0         0.130
# 1         0.478
# 2         0.894
# 3         0.855
# 4         0.537
# ...         ...
# 254882    0.298
# 254883    0.447
# 254884    0.690
# 254885    0.487
# 254886    0.840
#
# [254887 rows x 18 columns]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254887 entries, 0 to 254886
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              254887 non-null  object
#  1   song              254887 non-null  object
#  2   artist            254887 non-null  object
#  3   song_id           254887 non-null  object
#  4   uri               254887 non-null  object
#  5   acousticness      254867 non-null  float64
#  6   danceability      254867 non-null  float64
#  7   duration_ms       254867 non-null  float64
#  8   energy            254867 non-null  float64
#  9   instrumentalness  254867 non-null  float64
#  10  key               254867 non-null  float64
#  11  liveness          254867 non-null  float64
#  12  loudness          254867 non-null  float64
#  13  mode              254867 non-null  float64
#  14  speechiness       254867 non-null  float64
#  15  tempo             254867 non-null  float64
#  16  time_signature    254867 non-null  float64
#  17  valence           254867 non-null  float64
# dtypes: float64(13), object(5)
# memory usage: 36.9+ MB

# %%
# Drop rows that have null
merged = merged.dropna()
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254867 entries, 0 to 254886
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              254867 non-null  object
#  1   song              254867 non-null  object
#  2   artist            254867 non-null  object
#  3   song_id           254867 non-null  object
#  4   uri               254867 non-null  object
#  5   acousticness      254867 non-null  float64
#  6   danceability      254867 non-null  float64
#  7   duration_ms       254867 non-null  float64
#  8   energy            254867 non-null  float64
#  9   instrumentalness  254867 non-null  float64
#  10  key               254867 non-null  float64
#  11  liveness          254867 non-null  float64
#  12  loudness          254867 non-null  float64
#  13  mode              254867 non-null  float64
#  14  speechiness       254867 non-null  float64
#  15  tempo             254867 non-null  float64
#  16  time_signature    254867 non-null  float64
#  17  valence           254867 non-null  float64
# dtypes: float64(13), object(5)
# memory usage: 36.9+ MB

# %%
merged.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  254867.000000  254867.000000  2.548670e+05  254867.000000
# mean        0.201667       0.635467  2.423155e+05       0.653487
# std         0.228701       0.145827  5.869251e+04       0.186959
# min         0.000002       0.058600  2.968800e+04       0.000530
# 25%         0.027300       0.543000  2.075870e+05       0.524000
# 50%         0.107000       0.644000  2.349100e+05       0.673000
# 75%         0.304000       0.739000  2.681730e+05       0.802000
# max         0.996000       0.988000  1.561133e+06       0.998000
#
#        instrumentalness            key       liveness       loudness  \
# count     254867.000000  254867.000000  254867.000000  254867.000000
# mean           0.029151       5.281311       0.180003      -7.943069
# std            0.130725       3.591599       0.151156       3.547354
# min            0.000000       0.000000       0.014600     -42.391000
# 25%            0.000000       2.000000       0.086700     -10.005000
# 50%            0.000004       5.000000       0.122000      -7.218000
# 75%            0.000373       8.000000       0.230000      -5.321000
# max            0.986000      11.000000       0.997000       2.291000
#
#                 mode    speechiness          tempo  time_signature  \
# count  254867.000000  254867.000000  254867.000000   254867.000000
# mean        0.681712       0.079514     120.320712        3.967591
# std         0.465813       0.087168      27.650305        0.246580
# min         0.000000       0.022000      36.998000        1.000000
# 25%         0.000000       0.032800      99.069000        4.000000
# 50%         1.000000       0.043900     119.082000        4.000000
# 75%         1.000000       0.077900     136.086000        4.000000
# max         1.000000       0.951000     218.363000        5.000000
#
#              valence
# count  254867.000000
# mean        0.579500
# std         0.236797
# min         0.000010
# 25%         0.391000
# 50%         0.594000
# 75%         0.774000
# max         0.991000

# %% [markdown]
# ## Convert to Monthly

# %%
merged['date'] = pd.to_datetime(merged['date'])
# Out:
# /var/folders/bk/syp6nsbn40j6khhtbc03r73c0000gn/T/ipykernel_7383/2418851782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['date'] = pd.to_datetime(merged['date'])

# %%
merged['month'] = merged['date'].dt.strftime('%Y-%m')
merged['month'] = pd.to_datetime(merged['month'])
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254867 entries, 0 to 254886
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              254867 non-null  datetime64[ns]
#  1   song              254867 non-null  object
#  2   artist            254867 non-null  object
#  3   song_id           254867 non-null  object
#  4   uri               254867 non-null  object
#  5   acousticness      254867 non-null  float64
#  6   danceability      254867 non-null  float64
#  7   duration_ms       254867 non-null  float64
#  8   energy            254867 non-null  float64
#  9   instrumentalness  254867 non-null  float64
#  10  key               254867 non-null  float64
#  11  liveness          254867 non-null  float64
#  12  loudness          254867 non-null  float64
#  13  mode              254867 non-null  float64
#  14  speechiness       254867 non-null  float64
#  15  tempo             254867 non-null  float64
#  16  time_signature    254867 non-null  float64
#  17  valence           254867 non-null  float64
#  18  month             254867 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(13), object(4)
# memory usage: 38.9+ MB
# /var/folders/bk/syp6nsbn40j6khhtbc03r73c0000gn/T/ipykernel_7383/3274417395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['month'] = merged['date'].dt.strftime('%Y-%m')
# /var/folders/bk/syp6nsbn40j6khhtbc03r73c0000gn/T/ipykernel_7383/3274417395.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['month'] = pd.to_datetime(merged['month'])

# %%
monthly_df = merged.groupby('month').mean()
monthly_df = monthly_df.reset_index()
monthly_df = monthly_df[monthly_df['month'] <= '2021-10-01']
monthly_df
# Out:
#          month  acousticness  danceability  duration_ms    energy  \
# 0   1973-01-01      0.457472      0.550955  212694.5900  0.503980
# 1   1973-02-01      0.453098      0.555273  223715.0225  0.494452
# 2   1973-03-01      0.403588      0.566240  229079.4060  0.550828
# 3   1973-04-01      0.397373      0.556195  233286.8350  0.573691
# 4   1973-05-01      0.388143      0.551365  227164.6150  0.587730
# ..         ...           ...           ...          ...       ...
# 581 2021-06-01      0.236636      0.663382  192765.3875  0.604500
# 582 2021-07-01      0.217580      0.651402  193346.3260  0.635346
# 583 2021-08-01      0.210171      0.657075  193621.0700  0.642460
# 584 2021-09-01      0.213370      0.642172  205435.6775  0.638335
# 585 2021-10-01      0.211126      0.663372  201357.1680  0.643896
#
#      instrumentalness     key  liveness   loudness    mode  speechiness  \
# 0            0.052338  4.8075  0.161034 -11.355225  0.7025     0.046447
# 1            0.071676  4.5025  0.150142 -11.879192  0.7025     0.045740
# 2            0.071117  5.1100  0.177592 -10.948558  0.7500     0.048398
# 3            0.065822  5.3600  0.192299 -10.722660  0.7675     0.050146
# 4            0.072200  5.4025  0.207042 -10.490718  0.7700     0.063506
# ..                ...     ...       ...        ...     ...          ...
# 581          0.000449  5.2550  0.179318  -6.803228  0.6750     0.142282
# 582          0.002264  5.2460  0.193207  -6.248534  0.6860     0.114297
# 583          0.006846  5.3675  0.180522  -6.190460  0.6825     0.110391
# 584          0.002790  5.3075  0.183702  -6.215815  0.7025     0.122931
# 585          0.000310  4.9600  0.179111  -6.223496  0.7120     0.129959
#
#           tempo  time_signature   valence
# 0    121.812430          3.9325  0.616763
# 1    122.219197          3.9450  0.645075
# 2    123.727016          3.9140  0.686625
# 3    123.920433          3.9225  0.683426
# 4    121.525158          3.9500  0.671480
# ..          ...             ...       ...
# 581  122.396225          3.9575  0.464047
# 582  123.421260          3.9820  0.499031
# 583  124.751413          3.9675  0.523641
# 584  124.047017          3.9625  0.495950
# 585  123.849120          3.9480  0.503917
#
# [586 rows x 14 columns]

# %%
fig = plt.figure(figsize=[15, 8])

ax1 = fig.add_subplot(3, 3, 1)
ax2 = fig.add_subplot(3, 3, 2)
ax3 = fig.add_subplot(3, 3, 3)
ax4= fig.add_subplot(3, 3, 4)
ax5 = fig.add_subplot(3, 3, 5)
ax6 = fig.add_subplot(3, 3, 6)
ax7 = fig.add_subplot(3, 3, 7)
ax8 = fig.add_subplot(3, 3, 8)
ax9 = fig.add_subplot(3, 3, 9)

x = monthly_df['month']

y1 = monthly_df['acousticness']
y2 = monthly_df['danceability']
y3 = monthly_df['energy']
y4 = monthly_df['liveness']
y5 = monthly_df['loudness']
y6 = monthly_df['mode']
y7 = monthly_df['speechiness']
y8 = monthly_df['tempo']
y9 = monthly_df['valence']

ax1.plot(x, y1)
ax2.plot(x, y2)
ax3.plot(x, y3)
ax4.plot(x, y4)
ax5.plot(x, y5)
ax6.plot(x, y6)
ax7.plot(x, y7)
ax8.plot(x, y8)
ax9.plot(x, y9)


ax1.set_title('acousticness')
ax2.set_title('danceability')
ax3.set_title('energy')
ax4.set_title('liveness')
ax5.set_title('loudness')
ax6.set_title('mode')
ax7.set_title('speechiness')
ax8.set_title('tempo')
ax9.set_title('valence')


fig.tight_layout()
plt.show()

# %%
corr = monthly_df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="RdBu",annot=True)
plt.show()

# %% [markdown]
# ## 2. Unemployment Rate

# %%
unemp = pd.read_csv('/Users/kohtaasakura/PyDev/grad_thesis/economic_indicators/unemployment_rate.csv')
unemp
# Out:
#            DATE  UNRATE
# 0    1948-01-01     3.4
# 1    1948-02-01     3.8
# 2    1948-03-01     4.0
# 3    1948-04-01     3.9
# 4    1948-05-01     3.5
# ..          ...     ...
# 895  2022-08-01     3.7
# 896  2022-09-01     3.5
# 897  2022-10-01     3.7
# 898  2022-11-01     3.6
# 899  2022-12-01     3.5
#
# [900 rows x 2 columns]

# %%
unemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    900 non-null    object
#  1   UNRATE  900 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.2+ KB

# %%
unemp['DATE'] = pd.to_datetime(unemp['DATE'])
unemp = unemp[('1973-01-01' <= unemp['DATE']) & (unemp['DATE'] <= '2021-10-01')]
unemp
# Out:
#           DATE  UNRATE
# 300 1973-01-01     4.9
# 301 1973-02-01     5.0
# 302 1973-03-01     4.9
# 303 1973-04-01     5.0
# 304 1973-05-01     4.9
# ..         ...     ...
# 881 2021-06-01     5.9
# 882 2021-07-01     5.4
# 883 2021-08-01     5.2
# 884 2021-09-01     4.8
# 885 2021-10-01     4.5
#
# [586 rows x 2 columns]

# %%
plt.figure(figsize=(8,3))
plt.plot(unemp['DATE'], unemp['UNRATE'])
plt.ylabel('Uneproyment Rate')
plt.xlabel('Date')
plt.show()

# %%
fig = plt.figure(figsize=[15, 8])

ax1 = fig.add_subplot(3, 3, 1)
ax2 = fig.add_subplot(3, 3, 2)
ax3 = fig.add_subplot(3, 3, 3)
ax4 = fig.add_subplot(3, 3, 4)
ax5 = fig.add_subplot(3, 3, 5)
ax6 = fig.add_subplot(3, 3, 6)
ax7 = fig.add_subplot(3, 3, 7)
ax8 = fig.add_subplot(3, 3, 8)
ax9 = fig.add_subplot(3, 3, 9)

x = monthly_df['month']

y1 = monthly_df['acousticness']
y2 = monthly_df['danceability']
y3 = monthly_df['energy']
y4 = monthly_df['liveness']
y5 = monthly_df['loudness']
y6 = monthly_df['mode']
y7 = monthly_df['speechiness']
y8 = monthly_df['tempo']
y9 = monthly_df['valence']

ax1.plot(x, y1)
ax2.plot(x, y2)
ax3.plot(x, y3)
ax4.plot(x, y4)
ax5.plot(x, y5)
ax6.plot(x, y6)
ax7.plot(x, y7)
ax8.plot(x, y8)
ax9.plot(x, y9)

ax1_1 = ax1.twinx()
ax2_1 = ax2.twinx()
ax3_1 = ax3.twinx()
ax4_1 = ax4.twinx()
ax5_1 = ax5.twinx()
ax6_1 = ax6.twinx()
ax7_1 = ax7.twinx()
ax8_1 = ax8.twinx()
ax9_1 = ax9.twinx()

z = unemp['UNRATE']

ax1_1.plot(x, z, color='darkorange')
ax2_1.plot(x, z, color='darkorange')
ax3_1.plot(x, z, color='darkorange')
ax4_1.plot(x, z, color='darkorange')
ax5_1.plot(x, z, color='darkorange')
ax6_1.plot(x, z, color='darkorange')
ax7_1.plot(x, z, color='darkorange')
ax8_1.plot(x, z, color='darkorange')
ax9_1.plot(x, z, color='darkorange')

ax1.set_title('acousticness')
ax2.set_title('danceability')
ax3.set_title('energy')
ax4.set_title('liveness')
ax5.set_title('loudness')
ax6.set_title('mode')
ax7.set_title('speechiness')
ax8.set_title('tempo')
ax9.set_title('valence')


fig.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Simple OLS

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['acousticness']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     4.594
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):             0.0325
# Time:                        21:02:15   Log-Likelihood:                 759.94
# No. Observations:                 586   AIC:                            -1516.
# Df Residuals:                     584   BIC:                            -1507.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1800      0.010     17.148      0.000       0.159       0.201
# UNRATE         0.0035      0.002      2.143      0.032       0.000       0.007
# ==============================================================================
# Omnibus:                      133.365   Durbin-Watson:                   0.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              238.991
# Skew:                           1.347   Prob(JB):                     1.27e-52
# Kurtosis:                       4.591   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['danceability']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     101.2
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):           4.51e-22
# Time:                        21:02:16   Log-Likelihood:                 1264.0
# No. Observations:                 586   AIC:                            -2524.
# Df Residuals:                     584   BIC:                            -2515.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6786      0.004    152.769      0.000       0.670       0.687
# UNRATE        -0.0069      0.001    -10.062      0.000      -0.008      -0.006
# ==============================================================================
# Omnibus:                       37.597   Durbin-Watson:                   0.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.095
# Skew:                          -0.297   Prob(JB):                     5.00e-22
# Kurtosis:                       4.915   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['energy']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.7638
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):              0.383
# Time:                        21:02:17   Log-Likelihood:                 941.77
# No. Observations:                 586   AIC:                            -1880.
# Df Residuals:                     584   BIC:                            -1871.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6469      0.008     84.036      0.000       0.632       0.662
# UNRATE         0.0010      0.001      0.874      0.383      -0.001       0.003
# ==============================================================================
# Omnibus:                       30.877   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.294
# Skew:                          -0.283   Prob(JB):                     0.000107
# Kurtosis:                       2.345   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['liveness']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.135
# Method:                 Least Squares   F-statistic:                     92.10
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):           2.38e-20
# Time:                        21:02:20   Log-Likelihood:                 1652.6
# No. Observations:                 586   AIC:                            -3301.
# Df Residuals:                     584   BIC:                            -3293.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1588      0.002     69.383      0.000       0.154       0.163
# UNRATE         0.0034      0.000      9.597      0.000       0.003       0.004
# ==============================================================================
# Omnibus:                        0.169   Durbin-Watson:                   0.455
# Prob(Omnibus):                  0.919   Jarque-Bera (JB):                0.168
# Skew:                          -0.041   Prob(JB):                        0.920
# Kurtosis:                       2.984   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['loudness']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     23.97
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):           1.27e-06
# Time:                        21:02:20   Log-Likelihood:                -1218.0
# No. Observations:                 586   AIC:                             2440.
# Df Residuals:                     584   BIC:                             2449.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -6.4944      0.307    -21.160      0.000      -7.097      -5.892
# UNRATE        -0.2312      0.047     -4.896      0.000      -0.324      -0.138
# ==============================================================================
# Omnibus:                    18388.853   Durbin-Watson:                   0.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.666
# Skew:                           0.102   Prob(JB):                     2.71e-11
# Kurtosis:                       1.603   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['mode']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     48.51
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):           8.89e-12
# Time:                        21:02:21   Log-Likelihood:                 857.55
# No. Observations:                 586   AIC:                            -1711.
# Df Residuals:                     584   BIC:                            -1702.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6220      0.009     69.977      0.000       0.605       0.639
# UNRATE         0.0095      0.001      6.965      0.000       0.007       0.012
# ==============================================================================
# Omnibus:                        9.231   Durbin-Watson:                   0.277
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                9.222
# Skew:                          -0.282   Prob(JB):                      0.00994
# Kurtosis:                       3.243   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['speechiness']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     116.2
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):           7.86e-25
# Time:                        21:02:23   Log-Likelihood:                 1338.4
# No. Observations:                 586   AIC:                            -2673.
# Df Residuals:                     584   BIC:                            -2664.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1202      0.004     30.724      0.000       0.113       0.128
# UNRATE        -0.0065      0.001    -10.779      0.000      -0.008      -0.005
# ==============================================================================
# Omnibus:                       16.520   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.212
# Skew:                           0.371   Prob(JB):                     0.000302
# Kurtosis:                       2.662   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['tempo']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     58.40
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):           8.80e-14
# Time:                        21:02:23   Log-Likelihood:                -1477.8
# No. Observations:                 586   AIC:                             2960.
# Df Residuals:                     584   BIC:                             2968.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        116.7917      0.478    244.242      0.000     115.853     117.731
# UNRATE         0.5623      0.074      7.642      0.000       0.418       0.707
# ==============================================================================
# Omnibus:                        5.021   Durbin-Watson:                   0.325
# Prob(Omnibus):                  0.081   Jarque-Bera (JB):                3.663
# Skew:                           0.036   Prob(JB):                        0.160
# Kurtosis:                       2.619   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = unemp['UNRATE']
x = sm.add_constant(x)
y = monthly_df[['valence']]
y = y.values.reshape(-1,1)

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     38.18
# Date:                Fri, 13 Jan 2023   Prob (F-statistic):           1.21e-09
# Time:                        21:02:28   Log-Likelihood:                 795.87
# No. Observations:                 586   AIC:                            -1588.
# Df Residuals:                     584   BIC:                            -1579.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5206      0.010     52.720      0.000       0.501       0.540
# UNRATE         0.0094      0.002      6.179      0.000       0.006       0.012
# ==============================================================================
# Omnibus:                       42.478   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.209
# Skew:                          -0.057   Prob(JB):                     0.000498
# Kurtosis:                       2.219   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
