# %%
import pandas as pd

df = pd.read_pickle('charts_us_daily.pkl')

# %%
df.head()
# Out:
#          date                                   uri              artist_names  \
# 0  2017-01-01  spotify:track:4Km5HrUvYTaSUfiSGPJeQR       Migos, Lil Uzi Vert
# 1  2017-01-01  spotify:track:343YBumqHu19cGoGARUTsd                     Drake
# 2  2017-01-01  spotify:track:5aAx2yezTd8zXrkmtKl66Z     The Weeknd, Daft Punk
# 3  2017-01-01  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw  The Chainsmokers, Halsey
# 4  2017-01-01  spotify:track:6fujklziTHa8uoM5OQSfIo  Rae Sremmurd, Gucci Mane
#
#                             track_name
# 0  Bad and Boujee (feat. Lil Uzi Vert)
# 1                            Fake Love
# 2                              Starboy
# 3                               Closer
# 4                        Black Beatles

# %%
df.tail()
# Out:
#               date                                   uri  \
# 437379  2022-12-27  spotify:track:18vXApRmJSgQ6wG2ll9AOg
# 437380  2022-12-27  spotify:track:01Lr5YepbgjXAWR9iOEyH1
# 437381  2022-12-27  spotify:track:6PGoSes0D9eUDeeAafB2As
# 437382  2022-12-27  spotify:track:2i2qDe3dnTl6maUE31FO7c
# 437383  2022-12-27  spotify:track:7FmYn9e7KHMXcxqGSj9LjH
#
#                   artist_names           track_name
# 437379                  Polo G              RAPSTAR
# 437380              Chief Keef            Love Sosa
# 437381  Kendrick Lamar, Zacari  LOVE. FEAT. ZACARI.
# 437382        Lil Durk, Future              Mad Max
# 437383            Taylor Swift           Mastermind

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437384 entries, 0 to 437383
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          437384 non-null  object
#  1   uri           437384 non-null  object
#  2   artist_names  437384 non-null  object
#  3   track_name    437384 non-null  object
# dtypes: object(4)
# memory usage: 13.3+ MB

# %%
df.describe()
# Out:
#               date                                   uri artist_names  \
# count       437384                                437384       437384
# unique        2187                                 10591         4006
# top     2017-01-01  spotify:track:6gBFPUFcJLzWGx4lenP6h2   Juice WRLD
# freq           200                                  1892         9299
#
#         track_name
# count       437384
# unique        8527
# top     goosebumps
# freq          1892

# %%
uri_list = list(df['uri'].unique())

# %%
len(uri_list)
# Out:
# 10591

# %%
audio = pd.read_pickle('us_audio_features.pkl')
audio
# Out:
#        acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0            0.0611         0.926       343150   0.666          0.000000   11
# 1            0.1050         0.928       210937   0.481          0.000000    9
# 2            0.1650         0.681       230453   0.594          0.000003    7
# 3            0.4140         0.748       244960   0.524          0.000000    8
# 4            0.1420         0.794       291893   0.632          0.000000    0
# ...             ...           ...          ...     ...               ...  ...
# 10586        0.1870         0.491       169419   0.643          0.000000   10
# 10587        0.1260         0.380       223120   0.488          0.000007    9
# 10588        0.8590         0.735       175890   0.449          0.000000    2
# 10589        0.1480         0.587       199040   0.632          0.000010    9
# 10590        0.5930         0.505       163032   0.270          0.000000    9
#
# ...

# %%
merged = pd.merge(df, audio, how='left', on='uri')
merged
# Out:
#               date                                   uri  \
# 0       2017-01-01  spotify:track:4Km5HrUvYTaSUfiSGPJeQR
# 1       2017-01-01  spotify:track:343YBumqHu19cGoGARUTsd
# 2       2017-01-01  spotify:track:5aAx2yezTd8zXrkmtKl66Z
# 3       2017-01-01  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 4       2017-01-01  spotify:track:6fujklziTHa8uoM5OQSfIo
# ...            ...                                   ...
# 437379  2022-12-27  spotify:track:18vXApRmJSgQ6wG2ll9AOg
# 437380  2022-12-27  spotify:track:01Lr5YepbgjXAWR9iOEyH1
# 437381  2022-12-27  spotify:track:6PGoSes0D9eUDeeAafB2As
# 437382  2022-12-27  spotify:track:2i2qDe3dnTl6maUE31FO7c
# 437383  2022-12-27  spotify:track:7FmYn9e7KHMXcxqGSj9LjH
#
#                     artist_names                           track_name  \
# 0            Migos, Lil Uzi Vert  Bad and Boujee (feat. Lil Uzi Vert)
# 1                          Drake                            Fake Love
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 437384 entries, 0 to 437383
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              437384 non-null  object
#  1   uri               437384 non-null  object
#  2   artist_names      437384 non-null  object
#  3   track_name        437384 non-null  object
#  4   acousticness      437384 non-null  float64
#  5   danceability      437384 non-null  float64
#  6   duration_ms       437384 non-null  int64
#  7   energy            437384 non-null  float64
#  8   instrumentalness  437384 non-null  float64
#  9   key               437384 non-null  int64
#  10  liveness          437384 non-null  float64
#  11  loudness          437384 non-null  float64
#  12  mode              437384 non-null  int64
#  13  speechiness       437384 non-null  float64
#  14  tempo             437384 non-null  float64
# ...
